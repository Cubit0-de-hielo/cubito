# %% [markdown]
# <a href="https://colab.research.google.com/github/Cubit0-de-hielo/cubito/blob/main/Clase_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
#de donde saldran los datos
link = 'https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= '?raw=true'
url=link+code
df= pd.read_csv(url,sep=',',index_col=1)

# %%
df #datos acomodados
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.shape #numero de datos
# Out:
# (2484, 3)

# %%
df.info #informacion genral
# Out:
# <bound method DataFrame.info of                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.head() #principio de los datos
#el parentesis ayuda  delimita cuantos datos se veran, si no se ponde nada solo mostrata 5
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
df.tail() #final de los datos
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.isnull () #numero de datos(pero no ayuda ucho, false es para datos completos y true para datos faltantes)
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-09-05    False                   False                    False
# ...             ...                     ...                      ...
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
#
# [2484 rows x 3 columns]

# %%
df.isnull().sum() #alli ya te deice cuantos datos hay y cuantos faltan
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
df['Country'] #listados de datos
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
df['Country'].isin(['Mexico']).sum() # como sale un 0 sabemos qu mexico no apartece en este listado
# Out:
# 0

# %%
SL = df[df['Country']=='Sierra Leone']

# %%
SL
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0
# ...                  ...                     ...                      ...
# 2015-12-17  Sierra Leone                  8704.0                   3589.0
# 2015-12-22  Sierra Leone                  8704.0                   3589.0
# 2015-12-23  Sierra Leone                  8704.0                   3589.0
# 2015-12-29  Sierra Leone                  8704.0                   3589.0
# 2016-03-23  Sierra Leone                  8704.0                   3589.0
#
# [259 rows x 3 columns]

# %%
SL = SL.drop('Country',axis=1)

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0

# %%
SL[15:20]
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-10-22                  3223.0                    986.0
# 2014-10-25                  3389.0                   1008.0
# 2014-10-29                  3700.0                      NaN
# 2014-10-31                  3778.0                      NaN
# 2014-11-05                  4057.0                    893.0

# %%
SL.shape
# Out:
# (259, 2)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
SL.fillna(0.0,inplace=True)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
SL['No. of confirmed deaths'].mean() #casos totales
# Out:
# 3081.019305019305

# %%
SL['No. of confirmed cases'].mean() #promedio de casos
# Out:
# 7883.671814671815

# %%
Dates=SL.index[0:-1:10]
NCC=SL['No. of confirmed cases'][0:-1:10]
NCD=SL['No. of confirmed deaths'][0:-1:10]

# %%
#Graficacion de los datos de muertes y casos confirmados
plt.plot (Dates,NCC,'*--c',ms=7,label='Infectados')
plt.plot (Dates,NCD,'*-g',ms=8,label='Decesos')
plt.grid()
plt.title('Avance delebola en Sierra Leona')
plt.ylabel('Casos confirmados')
plt.xlabel('Periodo de tiepo')
plt.xticks(rotation=90,fontsize=8)
plt.legend()
plt.show()

# %%
PIvsD=100*SL['No. of confirmed deaths']/SL['No. of confirmed cases']
SL['PIvsD']=PIvsD

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0

# %%
recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL['recuperados']=recuperados

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
#
#             recuperados
# Date
# 2014-08-29        555.0
# 2014-09-05        703.0
# 2014-09-08        773.0
# 2014-09-12        809.0
# 2014-09-16        950.0
